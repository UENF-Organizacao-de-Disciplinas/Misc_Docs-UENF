# %% [markdown]
# ## Import libraries

# %%
from sklearn.datasets import load_iris
from sklearn import tree
import pandas as pd
import numpy as np

# %% [markdown]
# ## Loading and Creating Model

# %%
iris = load_iris()
clf = tree.DecisionTreeClassifier()
clf = clf.fit(iris.data, iris.target)
# Out:
# array([0.01333333, 0.        , 0.06405596, 0.92261071])

# %% [markdown]
# ## Printing in Text

# %%
from sklearn.tree.export import export_text
iris = load_iris()
X = iris['data']
y = iris['target']
decision_tree = tree.DecisionTreeClassifier(random_state=0, max_depth=2)
decision_tree = decision_tree.fit(X, y)
r = export_text(decision_tree, feature_names=iris['feature_names'])
print(r)
# Out:
# |--- petal width (cm) <= 0.80
# |   |--- class: 0
# |--- petal width (cm) >  0.80
# |   |--- petal width (cm) <= 1.75
# |   |   |--- class: 1
# |   |--- petal width (cm) >  1.75
# |   |   |--- class: 2

# %% [markdown]
# ## Plot Tree

# %%
tree.plot_tree(clf.fit(iris.data, iris.target))
# Out:
# [Text(167.4, 199.32, 'X[3] <= 0.8\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(141.64615384615385, 163.07999999999998, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(193.15384615384616, 163.07999999999998, 'X[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(103.01538461538462, 126.83999999999999, 'X[2] <= 4.95\ngini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(51.50769230769231, 90.6, 'X[3] <= 1.65\ngini = 0.041\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(25.753846153846155, 54.359999999999985, 'gini = 0.0\nsamples = 47\nvalue = [0, 47, 0]'),
#  Text(77.26153846153846, 54.359999999999985, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(154.52307692307693, 90.6, 'X[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(128.76923076923077, 54.359999999999985, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
# ...

# %% [markdown]
# ## GraphViz

# %%
conda install -c anaconda graphviz

# %%
pip install graphviz

# %%
import os
os.environ["PATH"] += os.pathsep + 'C:/Users/jpsei/Anaconda3/Library/bin/graphviz'

# %%
import graphviz 
dot_data = tree.export_graphviz(clf, out_file=None) 
graph = graphviz.Source(dot_data) 
graph.render("iris") 

dot_data = tree.export_graphviz(clf, out_file=None, 
                     feature_names=iris.feature_names,  
                     class_names=iris.target_names,  
                     filled=True, rounded=True,  
                     special_characters=True)  
graph = graphviz.Source(dot_data)  
graph

# %% [markdown]
# ## Predict

# %%
clf.feature_importances_
# Out:
# array([0.01333333, 0.        , 0.06405596, 0.92261071])

# %%
x=pd.DataFrame(iris.data, columns=iris.feature_names)
y=iris.target

# %%
x_pred = [(5.1,3.5,1.4,0.2),(4.9,3.0,1.4,0.2),(4.7,3.2,1.3,0.2),(4.6,3.1,1.5,0.2),(6.9,3.1,5.1,2.3),(6.4,2.8,5.6,2.2),(3.9,1.2,2.7,1.3)]

# %%
new_data = pd.DataFrame(data=x_pred,columns=['sepal length (cm)','sepal width (cm)', 'petal length (cm)', 'petal width (cm)'])

# %%
clf.predict(new_data)
# Out:
# array([0, 0, 0, 0, 2, 2, 1])
